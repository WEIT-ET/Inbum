# %%
# 그래프 해상도 설정
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.dpi' : '100'})
# %config InlineBackend.figure_format = 'retina'

# %%
# %%html
# <!--마크다운 표 정렬 설정-->
# <style> table {float:left} </style>
# Out:
# <!--마크다운 표 정렬 설정-->
# <style> table {float:left} </style>

# %% [markdown]
# ---

# %% [markdown]
# # 05 데이터 분석 기초! - 데이터 파악하기, 다루기 쉽게 수정하기

# %% [markdown]
# ## 05-1 데이터 파악하기

# %% [markdown]
# #### 데이터를 파악할 때 사용하는 명령어

# %% [markdown]
# | 함수       | 기능               |
# |------------|--------------------|
# | head()     | 앞부분 출력        |
# | tail()     | 뒷부분 출력        |
# | shape      | 행, 열 개수 출력   |
# | info()     | 변수 속성 출력     |
# | describe() | 요약 통계량 출력   |

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')

# %% [markdown]
# ### exam 데이터 파악하기

# %% [markdown]
# #### `head()` - 데이터 앞부분 확인하기

# %%
# 보통 데이터의 특성을 알아볼때 활용
exam.head()  # 앞에서부터 5행까지 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.head(10)  # 앞에서부터 10행까지 출력
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %% [markdown]
# #### `tail()` - 데이터 뒷부분 확인하기

# %%
exam.tail()  # 뒤에서부터 5행까지 출력
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.tail(10)  # 뒤에서부터 10행까지 출력

# 이 데이터의 갯수는?
# Out:
#     id  nclass  math  english  science
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# #### `shape` - 데이터가 몇 행, 몇 열로 구성되는지 알아보기

# %%
# 내장 함수로써 0차원 , 1차원(즉 행, 열이 나타난다)
exam.shape
# Out:
# (20, 5)

# %% [markdown]
# #### `info()` - 속성 파악하기

# %%
exam.info() # 리스트 순서, 열이름, null이 아닌 값, 데이터 타입
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %% [markdown]
# #### `describe()` - 요약 통계량 구하기

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# ### mpg 데이터 파악하기

# %%
# mpg 데이터 불러오기
mpg = pd.read_csv('mpg.csv')

# %%
mpg.head()  # mpg 앞부분 확인
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()  # mpg 뒷부분 확인
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
mpg.shape  # 행, 열 출력 234개의 행과 11개의 열
# Out:
# (234, 11)

# %%
mpg.info()  # 데이터 속성 확인 object는 문자열을 의미
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe()  # 요약 통계량 출력
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include = 'all')  # 문자 변수 요약 통계량 함께 출력

# NAN 값은 계산할 수 없어 나오는 특징 ==> 문자열의 평균은 존재하지 않는다!
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# unique        10    3         NaN         NaN    5        7
# top     auto(l4)    f         NaN         NaN    r      suv
# freq          83  106         NaN         NaN  168       62
# mean         NaN  NaN   16.858974   23.440171  NaN      NaN
# std          NaN  NaN    4.255946    5.954643  NaN      NaN
# min          NaN  NaN    9.000000   12.000000  NaN      NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN      NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN      NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN      NaN
# max          NaN  NaN   35.000000   44.000000  NaN      NaN

# %% [markdown]
# ### 함수와 메서드 차이 알아보기

# %% [markdown]
# **(1) 내장 함수**

# %%
var=[1,2,3,4,5]
sum(var)
max(var)
# Out:
# 5

# %% [markdown]
# **(2) 패키지 함수**

# %%
import pandas as pd
pd.read_csv('exam.csv')
df= pd.DataFrame({'x' : [1, 2, 3]})

# %% [markdown]
# **(3) 메서드**
#
# 매서드는 프레임워크나 내장 라이브러리 안 함수를 의미한다
#
# https://jonsyou.tistory.com/69

# %%
print(df.head())
df.info()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
df = pd.read_csv('exam.csv')
df.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
var = [1, 2, 3]
# 리스트는 행이라는 개념이 없으므로 head 출력 불과
var.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-ffce90703c7b> in <cell line: 2>()
#       1 var = [1, 2, 3]
# ----> 2 var.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(var)
# Out:
# list

# %% [markdown]
# ### 어트리뷰트 알아보기

# %%
df.head()  # 메서드
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df.shape   # 어트리뷰트는 총 5개 -> 열과 같은 말
# Out:
# (20, 5)

# %%
var.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 var.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# ---
# ## 05-2 변수명 바꾸기

# %% [markdown]
# ### 변수명 바꾸기

# %% [markdown]
# #### 1. 데이터 프레임 만들기

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2]})
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %% [markdown]
# #### 2. 데이터 프레임 복사본 만들기

# %%
df_new = df_raw.copy()  # 복사본 만들기 copy는 복사를 한다
df_new                  # 출력
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %% [markdown]
# 너 얇은 복사와 깊은 복사를 알아?
#
# deepcopy(), copy() 둘 다 내장함수
#
#  https://velog.io/@kkamyang/Python-%EC%96%95%EC%9D%80-%EB%B3%B5%EC%82%AC-%EA%B9%8A%EC%9D%80-%EB%B3%B5%EC%82%AC-shallow-copy-deep-copy

# %%
a=[1,2,3]
b = a
a is b
# Out:
# True

# %%
b[0] = 5
print(a)
print(b)
# Out:
# [5, 2, 3]
# [5, 2, 3]

# %%
a = [1, 2, 3]
b = a.copy()
a is b
# Out:
# False

# %%
b[0] = 5
print(a)
print(b)
# Out:
# [1, 2, 3]
# [5, 2, 3]

# %% [markdown]
# #### 3. 변수명 바꾸기

# %%
df_new = df_new.rename(columns = {'var2' : 'v2'})  # var2를 v2로 수정
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %% [markdown]
# ---
# ## 05-3 파생변수 만들기

# %% [markdown]
# ### 변수 조합해 파생변수 만들기

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
# 새로운 변수를 만들기 => ML 모델을 만들때 매우 중요
df['var_sum'] = df['var1'] + df['var2']  # var_sum 파생변수 만들기
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean'] = (df['var1'] + df['var2']) / 2  # var_mean 파생변수 만들기
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# ### mpg 통합 연비 변수 만들기

# %%
mpg['total'] = (mpg['cty'] + mpg['hwy']) / 2  # 통합 연비 변수 만들기
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
sum(mpg['total']) / len(mpg)  # total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()  # 통합 연비 변수 평균
# Out:
# 20.14957264957265

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기

# %% [markdown]
# #### 1. 기준값 정하기

# %%
mpg['total'].describe()  # 요약 통계량 출력
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
# 그래프 만들기
# 히스토그램을 보여준다
mpg['total'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### 2. 합격 판정 변수 만들기

# %%
import numpy as np

# %%
# 20 이상이면 pass, 그렇지 않으면 fail 부여
# 조건 만족 함수 -> np.where(조건, 참일때, 거짓일때)
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test
# 0   23.5  pass
# 1   25.0  pass
# 2   25.5  pass
# 3   25.5  pass
# 4   21.0  pass

# %% [markdown]
# #### 3. 빈도표로 합격 판정 자동차 수 살펴보기

# %%
# 카테고리별 갯수 출력
mpg['test'].value_counts()  # 연비 합격 빈도표 만들기
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
mpg['manufacturer'].value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
mpg['manufacturer'].unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
mpg['manufacturer'].nunique()
# Out:
# 15

# %% [markdown]
# #### 4. 막대 그래프로 빈도 표현하기

# %%
count_test = mpg['test'].value_counts()  # 연비 합격 빈도표를 변수에 할당

# %%
count_test.plot.bar()  # 연비 합격 빈도 막대 그래프 만들기
# barplot을 만들었다.
# Out:
# <Axes: >

# %% [markdown]
# #### 축 이름 회전하기

# %%
count_test.plot.bar(rot = 0)  # 축 이름 수평으로 만들기
# Out:
# <Axes: >

# %% [markdown]
# ### 중첩 조건문 활용하기

# %% [markdown]
# #### 1. 연비 등급 변수 만들기

# %%
# total 기준으로 A, B, C 등급 부여
mpg['grade'] = np.where(mpg['total'] >= 30, 'A',
               np.where(mpg['total'] >= 20, 'B', 'C'))

# 데이터 확인
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  test grade
# 0   23.5  pass     B
# 1   25.0  pass     B
# 2   25.5  pass     B
# 3   25.5  pass     B
# 4   21.0  pass     B

# %% [markdown]
# #### 2. 빈도표와 막대 그래프로 연비 등급 살펴보기

# %%
count_grade = mpg['grade'].value_counts()  # 등급 빈도표 만들기
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot = 0)  # 등급 빈도 막대 그래프 만들기 rotation 특성
# Out:
# <Axes: >

# %% [markdown]
# #### 알파벳순으로 막대 정렬하기

# %%
# 등급 빈도표 알파벳순 정렬
# sort_index를 통해 정렬!
count_grade = mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade = mpg['grade'].value_counts().sort_values(ascending=False)
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
# 등급 빈도 막대 그래프 만들기
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: >

# %% [markdown]
# ---
#
# ### (알아 두면 좋아요) 메서드 체이닝

# %%
# 출력 결과를 변수에 할당하는 방법
df = mpg['grade']
df = df.value_counts()
df = df.sort_index()
df
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
# 메서드 체이닝 -> 함수 뒤에 함수를 붙는거
# grade열의 갯수를 세서 오름차순으로 정렬
df = mpg['grade'].value_counts().sort_index()
df
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### 필요한 만큼 범주 만들기

# %%
# A, B, C, D 등급 변수 만들기
mpg['grade2'] = np.where(mpg['total'] >= 30, 'A',
                np.where(mpg['total'] >= 25, 'B',
                np.where(mpg['total'] >= 20, 'C', 'D')))

mpg['grade2'].value_counts().sort_index()
# Out:
# A     10
# B     33
# C     85
# D    106
# Name: grade2, dtype: int64

# %% [markdown]
# ### 목록에 해당하는 행으로 변수 만들기

# %%
# &과 |에 대해 알아보자
# &는 조건을 모두 만족해야한다 그러나 |는 or연산자로 하나만 만족해도 된다

mpg['size'] = np.where((mpg['category'] == 'compact') |
                       (mpg['category'] == 'subcompact') |
                       (mpg['category'] == '2seater'),
                       'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %%
# isin함수는 이름이 리스트 안 속성과 일치하면 small로 취급을 한다.
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')

mpg['size'].value_counts()
# Out:
# large    147
# small     87
# Name: size, dtype: int64

# %% [markdown]
# ---
# ### 정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('mpg.csv')

# 3. 데이터 파악하기
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.shape       # 행, 열 수
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: >
